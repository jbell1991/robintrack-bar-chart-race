# %% [markdown]
# # Robintrack Bar Chart Race
# You can create a bar chart race of the most popular stocks on Robinhood using data from [robintrack.net](https://robintrack.net/data-download). Simply download the data, we'll get it in wide format where the index is the date and each column is a stock symbol, then use the bar_chart_race package to create the graph.

# %%
# change directory to where you've downloaded the data
# %cd /Users/josephbell/Downloads/tmp2/popularity_export
# Out:
# /Users/josephbell/Downloads/tmp2/popularity_export

# %%
# imports
import bar_chart_race as bcr
import datetime as dt
from datetime import datetime
import glob
import os
import pandas as pd
import pandas_datareader.data as web

# %%
# generates a list of symbols in a python list from the csvs
stock_list = ['.'.join(filename.split('.')[:-1]) for filename in os.listdir("/Users/josephbell/Downloads/tmp2/popularity_export") if os.path.isfile(os.path.join('/Users/josephbell/Downloads/tmp2/popularity_export', filename))]
# sorts the list alphabetically
stock_list.sort()
# print(stock_list)
print('Number of stocks:', len(stock_list))
# Out:
# Number of stocks: 8460

# %%
# %%time

# clean data
def cleanPopularity(indir='/Users/josephbell/Downloads/tmp2/popularity_export'):
    '''Cleans data by adding a symbol name column, separating the date out,
       and dropping the timestamp.'''
    os.chdir(indir)
    fileList = glob.glob('*')
    for filename in fileList:
        df = pd.read_csv(filename)
        # using csv file name and creating a new column 'Symbol'
        df['Symbol'] = os.path.splitext(os.path.basename(filename))[0]
        # separating date and timestamp
        new = df["timestamp"].str.split(" ", n=1, expand=True)
        df["Date"] = new[0]
        df["Time"] = new[1]
        df.drop(columns=['timestamp'], inplace=True)
        # dropping duplicate dates
        df.drop_duplicates(subset='Date', keep='first', inplace=True)
        df.drop(columns=['Time'], inplace=True)
        df.to_csv('cleaned' + filename, index=False,encoding='utf-8-sig')
        
cleanPopularity()
# Out:
# CPU times: user 7min 4s, sys: 1min 43s, total: 8min 48s
# Wall time: 8min 59s

# %%
# check if the data has been properly cleaned
df = pd.read_csv('cleanedAAPL.csv')
df.head()
# Out:
#    users_holding Symbol        Date
# 0         150785   AAPL  2018-05-02
# 1         145510   AAPL  2018-05-03
# 2         143747   AAPL  2018-05-04
# 3         141424   AAPL  2018-05-05
# 4         141436   AAPL  2018-05-06

# %%
# %%time
# joins all of the csv files into one dataframe
# set working directory
os.chdir('/Users/josephbell/Downloads/tmp2/popularity_export') # change to your path
# find all csv files in the folder
# use glob pattern matching -> extension = 'csv'
# save result in list -> all_filenames
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# combine all files in the list
popularity_data = pd.concat([pd.read_csv(f) for f in all_filenames], sort=True)
# Out:
# CPU times: user 1min 58s, sys: 1min 6s, total: 3min 4s
# Wall time: 6min 27s

# %%
print(popularity_data.shape)
popularity_data.head()
# Out:
# (133138528, 4)
#          Date Symbol timestamp  users_holding
# 0  2018-05-02    OAS       NaN         1524.0
# 1  2018-05-03    OAS       NaN         1517.0
# 2  2018-05-04    OAS       NaN         1522.0
# 3  2018-05-05    OAS       NaN         1520.0
# 4  2018-05-06    OAS       NaN         1520.0

# %%
# dropping timestamp column
popularity_data.drop('timestamp', axis=1, inplace=True)
print(popularity_data.shape)
popularity_data.head()
# Out:
# (133138528, 3)
#          Date Symbol  users_holding
# 0  2018-05-02    OAS         1524.0
# 1  2018-05-03    OAS         1517.0
# 2  2018-05-04    OAS         1522.0
# 3  2018-05-05    OAS         1520.0
# 4  2018-05-06    OAS         1520.0

# %%
# drop null values
popularity_data = popularity_data.dropna()
print(popularity_data.shape)
popularity_data.head()
# Out:
# (5821323, 3)
#          Date Symbol  users_holding
# 0  2018-05-02    OAS         1524.0
# 1  2018-05-03    OAS         1517.0
# 2  2018-05-04    OAS         1522.0
# 3  2018-05-05    OAS         1520.0
# 4  2018-05-06    OAS         1520.0

# %% [markdown]
# # Get Names to Match Symbols
# We have the symbols for each stock, but that can become hard to follow especially when a stock you don't know the symbol for shows up on the list. You can download the name that goes with each symbol [here](https://robintrack.net/leaderboard) and click on download [full leaderboard as a csv.](https://robintrack.net/api/most_popular.csv?limit=100000)

# %%
names = pd.read_csv('/Users/josephbell/Downloads/leaderboard_2020-06-17_06-00-00.csv')
names = names.rename(columns = {'symbol': 'Symbol'})
names.drop('popularity', axis=1, inplace=True)
print(names.shape)
names.head()
# Out:
# (8170, 2)
#   Symbol               name
# 0      F         Ford Motor
# 1     GE                 GE
# 2    AAL  American Airlines
# 3    DIS             Disney
# 4    DAL    Delta Air Lines

# %%
# merging symbols with names
names_bc = popularity_data.merge(names, how ='inner', on = ('Symbol'))
print(names_bc.shape)
names_bc.head()
# Out:
# (5294479, 4)
#          Date Symbol  users_holding             name
# 0  2018-05-02    OAS         1524.0  Oasis Petroleum
# 1  2018-05-03    OAS         1517.0  Oasis Petroleum
# 2  2018-05-04    OAS         1522.0  Oasis Petroleum
# 3  2018-05-05    OAS         1520.0  Oasis Petroleum
# 4  2018-05-06    OAS         1520.0  Oasis Petroleum

# %%
# drop null values
names_bc = names_bc.dropna()
print(names_bc.shape)
names_bc.head()
# Out:
# (5059655, 4)
#          Date Symbol  users_holding             name
# 0  2018-05-02    OAS         1524.0  Oasis Petroleum
# 1  2018-05-03    OAS         1517.0  Oasis Petroleum
# 2  2018-05-04    OAS         1522.0  Oasis Petroleum
# 3  2018-05-05    OAS         1520.0  Oasis Petroleum
# 4  2018-05-06    OAS         1520.0  Oasis Petroleum

# %% [markdown]
# # Dealing with Carnival
# For some reason when I pivot the data to convert it to wide format, the Carnival Cruise Lines (CCL) data gets corrupted so I save it to a csv file. We'll need this later.

# %%
carnival = names_bc[names_bc.values == 'CCL']
print(carnival.shape)
carnival.tail()
# Out:
# (763, 4)
#                Date Symbol  users_holding      name
# 5221970  2020-06-15    CCL       499581.0  Carnival
# 5221971  2020-06-16    CCL       502004.0  Carnival
# 5221972  2020-06-17    CCL       502422.0  Carnival
# 5221973  2020-06-18    CCL       502941.0  Carnival
# 5221974  2020-06-19    CCL       501509.0  Carnival

# %%
# convert to a csv
carnival.to_csv('carnival.csv')

# %%
names_bc['Date'].nunique()
# Out:
# 763

# %%
# pivot data so that the index is the date and each column is a company name
names_pivot = pd.pivot_table(names_bc, index=['Date'], columns=['name'])
# fill null values with 0 users holding
names_pivot = names_pivot.fillna(0)
names_pivot
# Out:
#            users_holding                                                  \
# name       1-800-Flowers 10x Genomics    111 1347 PIH 180 Degree Capital
# Date
# 2018-05-02         747.0          0.0    0.0     33.0              770.0
# 2018-05-03         756.0          0.0    0.0     33.0              762.0
# 2018-05-04         758.0          0.0    0.0     33.0              760.0
# 2018-05-05         755.0          0.0    0.0     33.0              753.0
# 2018-05-06         755.0          0.0    0.0     33.0              753.0
# ...                  ...          ...    ...      ...                ...
# 2020-06-15        2106.0       1500.0  393.0     19.0              994.0
# 2020-06-16        2097.0       1524.0  400.0     19.0             1021.0
# 2020-06-17        2075.0       1542.0  396.0     19.0             1020.0
# 2020-06-18        2070.0       1553.0  398.0     31.0             1027.0
# 2020-06-19        2089.0       1558.0  396.0     26.0             1036.0
#
#                                                                              \
# name       1Life Healthcare 1st Constitution Bank 1st Source 21Vianet Group
# Date
# 2018-05-02              0.0                  24.0       21.0          114.0
# 2018-05-03              0.0                  24.0       20.0          115.0
# 2018-05-04              0.0                  24.0       20.0          116.0
# 2018-05-05              0.0                  24.0       20.0          118.0
# 2018-05-06              0.0                  24.0       20.0          118.0
# ...                     ...                   ...        ...            ...
# 2020-06-15           4323.0                  44.0       73.0          343.0
# 2020-06-16           4312.0                  45.0       72.0          337.0
# 2020-06-17           4306.0                  44.0       71.0          326.0
# 2020-06-18           4305.0                  44.0       71.0          508.0
# 2020-06-19           4295.0                  44.0       73.0          460.0
#
#                                ...                                         \
# name       22nd Century Group  ...  iStar inTEST j2 Global nVent Electric
# Date                           ...
# 2018-05-02            34789.0  ...   52.0  316.0      82.0            0.0
# 2018-05-03            34723.0  ...   57.0  318.0      84.0            0.0
# 2018-05-04            34729.0  ...   58.0  322.0      83.0            4.0
# 2018-05-05            34477.0  ...   56.0  317.0      86.0           17.0
# 2018-05-06            34477.0  ...   56.0  317.0      86.0           17.0
# ...                       ...  ...    ...    ...       ...            ...
# 2020-06-15            50758.0  ...  408.0  493.0     251.0          221.0
# 2020-06-16            50898.0  ...  409.0  492.0     258.0          222.0
# 2020-06-17            50830.0  ...  408.0  493.0     259.0          222.0
# 2020-06-18            50821.0  ...  412.0  496.0     261.0          225.0
# 2020-06-19            50857.0  ...  403.0  495.0     266.0          225.0
#
#                                                                         \
# name       nnovator S&P 500 Power Buffer nnovator S&P 500 Ultra Buffer
# Date
# 2018-05-02                           0.0                           0.0
# 2018-05-03                           0.0                           0.0
# 2018-05-04                           0.0                           0.0
# 2018-05-05                           0.0                           0.0
# 2018-05-06                           0.0                           0.0
# ...                                  ...                           ...
# 2020-06-15                           2.0                           2.0
# 2020-06-16                           2.0                           2.0
# 2020-06-17                           2.0                           2.0
# 2020-06-18                           3.0                           2.0
# 2020-06-19                           3.0                           2.0
#
#                                                        \
# name       scPharmaceuticals uniQure vTv Therapeutics
# Date
# 2018-05-02             117.0     0.0           1716.0
# 2018-05-03             121.0     0.0           1664.0
# 2018-05-04             118.0     0.0           1632.0
# 2018-05-05             116.0     0.0           1617.0
# 2018-05-06             116.0     0.0           1617.0
# ...                      ...     ...              ...
# 2020-06-15             191.0   599.0           3009.0
# 2020-06-16             192.0   594.0           3220.0
# 2020-06-17             195.0   594.0           3740.0
# 2020-06-18             193.0   590.0           3780.0
# 2020-06-19             189.0   589.0           3609.0
#
#
# name       |Xtrackers J.P. Morgan ESG USD High Yield Corporate Bond
# Date
# 2018-05-02                                                0.0
# 2018-05-03                                                0.0
# 2018-05-04                                                0.0
# 2018-05-05                                                0.0
# 2018-05-06                                                0.0
# ...                                                       ...
# 2020-06-15                                                8.0
# 2020-06-16                                                8.0
# 2020-06-17                                                8.0
# 2020-06-18                                                8.0
# 2020-06-19                                                8.0
#
# [763 rows x 7645 columns]

# %%
# save pivot table as a csv
names_pivot.to_csv('names_pivot2.csv')

# %% [markdown]
# # Use Excel
# Edit the pivot table csv in excel by deleting the top row with users_holding. Delete cell A1 where name is, shift cells up and delete row 2 from cell B2 to the right and shift cells up. Save the file and we'll reload it in. Search the spreadsheet for 'carnvial'. You may notice that the numbers in this column do not match the numbers from the dataframe. You can insert the correct numbers from the carnival csv prior to pivoting.
#
# It's a mystery as to why the pivot caused this, but I found the error as Carivnal wasn't showing up on the most popular stocks when it should have. There may be other errors, but everything else looked normal from spot checks.  In some cases a symbol gets changed like in the case of Draft Kings where it briefly makes an appearance on the list in 2018 before it was public because another company had the symbol DKNG in 2018.

# %%
# reload the csv after editing it
df = pd.read_csv('/Users/josephbell/Downloads/tmp2/popularity_export/names_pivot2.csv')
print(df.shape)
df.head()
# Out:
# (763, 7646)
#      Date  1-800-Flowers  10x Genomics  111  1347 PIH  180 Degree Capital  \
# 0  5/2/18            747             0    0        33                 770
# 1  5/3/18            756             0    0        33                 762
# 2  5/4/18            758             0    0        33                 760
# 3  5/5/18            755             0    0        33                 753
# 4  5/6/18            755             0    0        33                 753
#
#    1Life Healthcare  1st Constitution Bank  1st Source  21Vianet Group  ...  \
# 0                 0                     24          21             114  ...
# 1                 0                     24          20             115  ...
# 2                 0                     24          20             116  ...
# 3                 0                     24          20             118  ...
# 4                 0                     24          20             118  ...
#
#    iStar  inTEST  j2 Global  nVent Electric  nnovator S&P 500 Power Buffer  \
# 0     52     316         82               0                              0
# 1     57     318         84               0                              0
# 2     58     322         83               4                              0
# 3     56     317         86              17                              0
# 4     56     317         86              17                              0
#
#    nnovator S&P 500 Ultra Buffer  scPharmaceuticals  uniQure  \
# 0                              0                117        0
# 1                              0                121        0
# 2                              0                118        0
# 3                              0                116        0
# 4                              0                116        0
#
#    vTv Therapeutics  |Xtrackers J.P. Morgan ESG USD High Yield Corporate Bond
# 0              1716                                                  0
# 1              1664                                                  0
# 2              1632                                                  0
# 3              1617                                                  0
# 4              1617                                                  0
#
# [5 rows x 7646 columns]

# %%
# make sure you're in the right directory
# %cd /Users/josephbell/Downloads/tmp2/popularity_export
# Out:
# /Users/josephbell/Downloads/tmp2/popularity_export

# %% [markdown]
# # Get Trading Days
# In order to reduce the time the bar chart race takes to complete and make it flow smoothly we don't need to look at every single calendar day. Instead we can just take trading days, which excludes weekends and holidays. We'll get the trading days from AAPL and then merge them with the popularity data, which is collected everyday.

# %%
# get trading dates by getting prices for one stock
def get_stock_data(): 
    tickers = ['AAPL']

    start = dt.datetime(2018, 5, 2)
    end = dt.datetime(2020, 6, 19)

    if not os.path.exists('pricedata'):
        os.makedirs('pricedata')
  
    for ticker in tickers:
        print(ticker)
        try : 
            df = web.DataReader(ticker, 'yahoo', start, end).drop(['High','Low','Open','Adj Close'], axis=1)
            df['Symbol'] = ticker
            print(df.head())
            df.to_csv('pricedata/{}.csv'. format(ticker))
            print(ticker, 'downloaded')
        except Exception as e: 
            pass
            # print(e, 'error')

print(get_stock_data())
# Out:
# AAPL
#                  Close      Volume Symbol
# Date
# 2018-05-02  176.570007  66539400.0   AAPL
# 2018-05-03  176.889999  34068200.0   AAPL
# 2018-05-04  183.830002  56201300.0   AAPL
# 2018-05-07  185.160004  42451400.0   AAPL
# 2018-05-08  186.050003  28402800.0   AAPL
# AAPL downloaded
# None

# %%
# get trading dates from a single stock
dates = pd.read_csv('/Users/josephbell/Downloads/tmp2/popularity_export/pricedata/AAPL.csv')
dates.drop(['Close', 'Volume', 'Symbol'], axis=1, inplace=True)
dates['Date'] = pd.to_datetime(dates['Date'])
dates.head()
# Out:
#         Date
# 0 2018-05-02
# 1 2018-05-03
# 2 2018-05-04
# 3 2018-05-07
# 4 2018-05-08

# %%
# get date in matching format
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date  1-800-Flowers  10x Genomics  111  1347 PIH  180 Degree Capital  \
# 0 2018-05-02            747             0    0        33                 770
# 1 2018-05-03            756             0    0        33                 762
# 2 2018-05-04            758             0    0        33                 760
# 3 2018-05-05            755             0    0        33                 753
# 4 2018-05-06            755             0    0        33                 753
#
#    1Life Healthcare  1st Constitution Bank  1st Source  21Vianet Group  ...  \
# 0                 0                     24          21             114  ...
# 1                 0                     24          20             115  ...
# 2                 0                     24          20             116  ...
# 3                 0                     24          20             118  ...
# 4                 0                     24          20             118  ...
#
#    iStar  inTEST  j2 Global  nVent Electric  nnovator S&P 500 Power Buffer  \
# 0     52     316         82               0                              0
# 1     57     318         84               0                              0
# 2     58     322         83               4                              0
# 3     56     317         86              17                              0
# 4     56     317         86              17                              0
#
#    nnovator S&P 500 Ultra Buffer  scPharmaceuticals  uniQure  \
# 0                              0                117        0
# 1                              0                121        0
# 2                              0                118        0
# 3                              0                116        0
# 4                              0                116        0
#
#    vTv Therapeutics  |Xtrackers J.P. Morgan ESG USD High Yield Corporate Bond
# 0              1716                                                  0
# 1              1664                                                  0
# 2              1632                                                  0
# 3              1617                                                  0
# 4              1617                                                  0
#
# [5 rows x 7646 columns]

# %%
# spot check if carnival numbers are correct
df['Carnival']
# Out:
# 0        1003
# 1        1001
# 2         997
# 3         998
# 4         998
#         ...
# 758    499581
# 759    502004
# 760    502422
# 761    502941
# 762    501509
# Name: Carnival, Length: 763, dtype: int64

# %%
# merge on date to get rid of non-trading days
df2 = df.merge(dates, how='inner', on=('Date'))
print(df2.shape)
df2.head()
# Out:
# (526, 7646)
#         Date  1-800-Flowers  10x Genomics  111  1347 PIH  180 Degree Capital  \
# 0 2018-05-02            747             0    0        33                 770
# 1 2018-05-03            756             0    0        33                 762
# 2 2018-05-04            758             0    0        33                 760
# 3 2018-05-07            755             0    0        33                 753
# 4 2018-05-08            752             0    0        33                 750
#
#    1Life Healthcare  1st Constitution Bank  1st Source  21Vianet Group  ...  \
# 0                 0                     24          21             114  ...
# 1                 0                     24          20             115  ...
# 2                 0                     24          20             116  ...
# 3                 0                     24          20             118  ...
# 4                 0                     25          21             119  ...
#
#    iStar  inTEST  j2 Global  nVent Electric  nnovator S&P 500 Power Buffer  \
# 0     52     316         82               0                              0
# 1     57     318         84               0                              0
# 2     58     322         83               4                              0
# 3     56     317         86              17                              0
# 4     61     305         94              28                              0
#
#    nnovator S&P 500 Ultra Buffer  scPharmaceuticals  uniQure  \
# 0                              0                117        0
# 1                              0                121        0
# 2                              0                118        0
# 3                              0                116        0
# 4                              0                109        0
#
#    vTv Therapeutics  |Xtrackers J.P. Morgan ESG USD High Yield Corporate Bond
# 0              1716                                                  0
# 1              1664                                                  0
# 2              1632                                                  0
# 3              1617                                                  0
# 4              1545                                                  0
#
# [5 rows x 7646 columns]

# %%
# set date column as index
df2 = df2.set_index('Date')
df2.head()
# Out:
#             1-800-Flowers  10x Genomics  111  1347 PIH  180 Degree Capital  \
# Date
# 2018-05-02            747             0    0        33                 770
# 2018-05-03            756             0    0        33                 762
# 2018-05-04            758             0    0        33                 760
# 2018-05-07            755             0    0        33                 753
# 2018-05-08            752             0    0        33                 750
#
#             1Life Healthcare  1st Constitution Bank  1st Source  \
# Date
# 2018-05-02                 0                     24          21
# 2018-05-03                 0                     24          20
# 2018-05-04                 0                     24          20
# 2018-05-07                 0                     24          20
# 2018-05-08                 0                     25          21
#
#             21Vianet Group  22nd Century Group  ...  iStar  inTEST  j2 Global  \
# Date                                            ...
# 2018-05-02             114               34789  ...     52     316         82
# 2018-05-03             115               34723  ...     57     318         84
# 2018-05-04             116               34729  ...     58     322         83
# 2018-05-07             118               34477  ...     56     317         86
# 2018-05-08             119               34427  ...     61     305         94
#
#             nVent Electric  nnovator S&P 500 Power Buffer  \
# Date
# 2018-05-02               0                              0
# 2018-05-03               0                              0
# 2018-05-04               4                              0
# 2018-05-07              17                              0
# 2018-05-08              28                              0
#
#             nnovator S&P 500 Ultra Buffer  scPharmaceuticals  uniQure  \
# Date
# 2018-05-02                              0                117        0
# 2018-05-03                              0                121        0
# 2018-05-04                              0                118        0
# 2018-05-07                              0                116        0
# 2018-05-08                              0                109        0
#
#             vTv Therapeutics  \
# Date
# 2018-05-02              1716
# 2018-05-03              1664
# 2018-05-04              1632
# 2018-05-07              1617
# 2018-05-08              1545
#
#             |Xtrackers J.P. Morgan ESG USD High Yield Corporate Bond
# Date
# 2018-05-02                                                  0
# 2018-05-03                                                  0
# 2018-05-04                                                  0
# 2018-05-07                                                  0
# 2018-05-08                                                  0
#
# [5 rows x 7645 columns]

# %% [markdown]
# # Create the Bar Chart Race
# Now that our data is in the correct format we can create our bar chart race! You can edit the parameters to customize your graph. A list of parameters can be found [here](https://www.dexplo.org/bar_chart_race/). Note: this does take a while to run. Once it is done you can scroll to the bottom of the notebook to view your chart or save it as a file under filename.

# %%
bcr.bar_chart_race(df=df2, n_bars=30, filename='Robinhood_barchart_race3.mp4', title='Most Popular Stocks on Robinhood by Users Holding',
                   period_fmt='%B %d, %Y', filter_column_colors=True,
                   period_summary_func=lambda v, r: {'x': .95, 'y': .09,
                   's': '@joebellowns',
                   'ha': 'right', 'size': 8, 'family': 'Helvetica'})
# Out:
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 134 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 135 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 136 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 137 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 138 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 139 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 142 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 143 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 147 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 149 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 150 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 151 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 155 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 156 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 157 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 158 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 159 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 746 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 747 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 751 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 752 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 753 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 754 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 756 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 757 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 758 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 760 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 761 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 762 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 763 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 764 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 765 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 766 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 767 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 848 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 852 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 853 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 854 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 857 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 859 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 867 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 870 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 871 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 872 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 873 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 874 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 875 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 876 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 877 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 878 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 879 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 888 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 889 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 895 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 897 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 898 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 899 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 907 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 909 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 930 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1318 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1319 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1321 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1322 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1323 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1325 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1326 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1328 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1367 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1416 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1419 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1420 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1421 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1422 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1423 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1424 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1425 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1426 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1427 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1428 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1429 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1430 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1431 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1432 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1433 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1434 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1435 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1437 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1438 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1439 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1441 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1442 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1443 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1444 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1445 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1446 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1447 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1448 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1451 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1454 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1455 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1476 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1477 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1480 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1481 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1482 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1483 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1484 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1485 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1486 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1487 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1515 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1517 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1518 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1519 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1525 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1526 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1527 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1528 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1529 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1530 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1531 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1533 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1534 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1535 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1537 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1538 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1539 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1541 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1547 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1549 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1550 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1551 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1553 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1554 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1555 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1556 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1558 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1559 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1560 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1561 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1562 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1564 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1565 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1566 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1568 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1595 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1596 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1597 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1598 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1599 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1622 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1624 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1625 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1627 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1628 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1630 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1631 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1649 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1650 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1651 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1653 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1654 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1655 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1656 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1730 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1731 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1732 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1733 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1737 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1738 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1741 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1743 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1745 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1746 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1747 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1748 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1750 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1751 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1752 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1753 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1754 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1755 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1756 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1757 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1758 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1759 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1760 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1761 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1762 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1763 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1764 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1765 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1766 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1767 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1768 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1769 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1770 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1771 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1772 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1773 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1774 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1775 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1786 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1787 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1788 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1789 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1790 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1791 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1792 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1793 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 1794 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7553 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7554 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7555 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7556 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7558 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7559 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7560 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7561 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7562 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7563 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7564 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7565 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7566 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7567 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7568 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7569 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7570 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7571 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7572 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7573 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7574 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7575 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7576 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7577 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7578 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7616 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7617 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7618 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7619 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7626 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7627 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7628 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7629 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7630 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7631 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7632 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7633 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7634 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7635 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7636 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7637 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7638 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7639 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7640 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7641 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7642 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7643 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7644 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7645 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7646 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7647 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7648 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7649 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7650 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7651 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7652 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7653 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7654 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7655 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7656 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7657 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7658 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7659 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7660 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7661 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7662 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7663 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7664 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7665 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7666 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7667 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7668 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7669 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7670 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7671 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7672 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7673 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7674 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7675 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7676 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7677 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7678 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/josephbell/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 7679 missing from current font.
#   font.load_char(ord(s), flags=flags)
